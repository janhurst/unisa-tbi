# %% [markdown]
# # Descriptive Statistics for PECARN TBI dataset
# This notebook generates plots for descriptive statistics of the variables in the cleaned PECARN TBI dataset

# %%
# magic to help out Jupyter notebooks
import os, sys
sys.path.append(os.path.abspath('..\src'))

# %%
import pandas as pd 

# allow log messages in notebooks
import logging
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# use the pecarn module to bring the PECARN dataset into the notebook
from data import pecarn

# cleaned PECARN data
df = pecarn.clean(pecarn.load(fromCsv=False))
# Out:
# INFO:data.pecarn.load:Loading from CSV file c:\Jan\Capstone\eda\TBI PUD 10-08-2013.csv

# %%
for col in df.select_dtypes(include='boolean'):
    df[col] = df[col].astype('int')

# %%
for col in pecarn_cleaned:
    pass

# %%
g = df.groupby('PosIntFinal')

# %%
import seaborn as sns


sns.countplot(data = df, x='AMS', hue='PosIntFinal')

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-28-88a38b1a8a6d> in <module>
#       1 from pandas.plotting import scatter_matrix
# ----> 2 scatter_matrix(df)
#
# ~\.conda\envs\tbi\lib\site-packages\pandas\plotting\_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     121     """
#     122     plot_backend = _get_plot_backend("matplotlib")
# --> 123     return plot_backend.scatter_matrix(
#     124         frame=frame,
#     125         alpha=alpha,
#
# ~\.conda\envs\tbi\lib\site-packages\pandas\plotting\_matplotlib\misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      46     for a in df.columns:
#      47         values = df[a].values[mask[a].values]
# ...

# %%
for variable in pecarn:
    create_figure
    savefig()
# Out:
# AMS             boolean
# AMSAgitated     boolean
# AMSOth          boolean
# AMSRepeat       boolean
# AMSSleep        boolean
#                  ...
# SeizOccur      category
# Vomit           boolean
# VomitLast      category
# VomitNbr       category
# VomitStart     category
# Length: 67, dtype: object
