# %% [markdown]
# # Seizures
#
# *Seiz* is post-traumatic seizure?
#
# *SeizOccur* is When did the post-traumatic seizure SeizOccur
#
# *SeizLen* is Duration of post-traumatic seizure

# %%
# call the 02-data-cleaning.ipynb notebook to bring the pecarn_tbi dataframe and the cleaned dataframe into the environment
# %cd -q ../notebooks
# %run ./02-data-cleaning.ipynb
# %cd -q -
# Out:
# START: 00-load-raw-data.ipynb
#   PECARN TBI data read from c:\Jan\Capstone\data/TBI PUD 10-08-2013.csv into "pecarn_tbi" dataframe
# START: 01-data-cleaning.ipynb
#   Dropping AgeInMonth
#   Renaming AgeinYears to Age
#   Dropping AgeTwoPlus
#   Dropping EmplType
#   Dropping AgeInMonth
#   Dropping High_impact_InjSev
#   Renaming InjuryMech to Injury_Mechanism
#   Renaming ActNorm to Acting_Normal
#   Setting Acting_Normal missing data to 1 (Yes)
#   The cleaned dataset is now available in a dataframe named "data"

# %%
pecarn_tbi[['Seiz', 'SeizOccur', 'SeizLen']].isna().sum()
# Out:
# Seiz         912
# SeizOccur     71
# SeizLen      117
# dtype: int64

# %%
data[['Seiz', 'SeizOccur', 'SeizLen']].isna().sum()
# Out:
# Seiz         912
# SeizOccur     71
# SeizLen      117
# dtype: int64

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pecarn_tbi[pecarn_tbi['Seiz'].isna()].head(10)
# Out:
#        EmplType Certification InjuryMech High_impact_InjSev Amnesia_verb  \
# PatNum
# 3             5             3          5                  2          NaN
# 168           4             3          1                  2           91
# 193           5             2          4                  2            0
# 216           3             3          8                  3           91
# 341           5             3         11                  2            1
# 352           3             3          8                  2           91
# 398           4             3          8                  3           91
# 448           5             3          1                  3          NaN
# 457           5             3        NaN                NaN            1
# 483           4             3          4                  2            1
#
#        LOCSeparate LocLen Seiz SeizOccur SeizLen ActNorm HA_verb HASeverity  \
# PatNum
# ...
