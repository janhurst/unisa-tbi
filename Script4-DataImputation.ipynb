# %% [markdown]
# # This is the fourth task in our module which basically does the imputation with sci-kit learning in python.

# %%
# %run Script3-DataRemoval.ipynb
# Out:
# The task Script2-DataLabelling.ipynb starts.....
# PatNum is unique: True
# EmplType is unique: False
# Certification is unique: False
# InjuryMech is unique: False
# High_impact_InjSev is unique: False
# Amnesia_verb is unique: False
# LOCSeparate is unique: False
# LocLen is unique: False
# Seiz is unique: False
# SeizOccur is unique: False
# SeizLen is unique: False
# ActNorm is unique: False
# HA_verb is unique: False
# HASeverity is unique: False
# HAStart is unique: False
# Vomit is unique: False
# VomitNbr is unique: False
# VomitStart is unique: False
# VomitLast is unique: False
# Dizzy is unique: False
# Intubated is unique: False
# Paralyzed is unique: False
# Sedated is unique: False
# GCSEye is unique: False
# GCSVerbal is unique: False
# GCSMotor is unique: False
# GCSTotal is unique: False
# GCSGroup is unique: False
# AMS is unique: False
# AMSAgitated is unique: False
# AMSSleep is unique: False
# AMSSlow is unique: False
# AMSRepeat is unique: False
# ...

# %% [markdown]
# Here we use SimpleImputer to impute the missing values for all the colums that has a missing number of %. The age is not ignored as there is no missing values in it and no issues.

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
TBI_IMP = imp.fit_transform(TBI)

# %% [markdown]
# The output is changed to numpy and needs some transformation to be back as pandas and header is missing. The good thing here is the imputation is done.

# %%
TBI_IMP
# Out:
# array([['No', 'Not applicable', 'Not applicable', ..., 'Not applicable',
#         'Not applicable', 'Not applicable'],
#        ['No', 'Not applicable', 'Not applicable', ...,
#         '< 1 hr before ED evaluation', '> 2 times',
#         '1 - 4 hrs after event'],
#        ['Yes', 'Yes', 'No', ..., 'Not applicable', 'Not applicable',
#         'Not applicable'],
#        ...,
#        ['No', 'Not applicable', 'Not applicable', ..., 'Not applicable',
#         'Not applicable', 'Not applicable'],
#        ['No', 'Not applicable', 'Not applicable', ..., 'Not applicable',
#         'Not applicable', 'Not applicable'],
#        ['No', 'Not applicable', 'Not applicable', ..., 'Not applicable',
#         'Not applicable', 'Not applicable']], dtype=object)

# %% [markdown]
# Here we are converting the numpy array back to pandas and appending with the lost header

# %%
x =list(TBI.columns)
TBI = pd.DataFrame(data=TBI_IMP, columns= x)

# %% [markdown]
# Check once if you cant see any number of missing records

# %%
print(f" % of NA's in each colum is \n\n{TBI.isnull().sum()/TBI.shape[0] * 100} appropriate action required")
# Out:
#  % of NA's in each colum is
#
# AMS               0.0
# AMSAgitated       0.0
# AMSOth            0.0
# AMSRepeat         0.0
# AMSSleep          0.0
# AMSSlow           0.0
# ActNorm           0.0
# AgeinYears        0.0
# Amnesia_verb      0.0
# Clav              0.0
# ClavFace          0.0
# ClavFro           0.0
# ClavNeck          0.0
# ClavOcc           0.0
# ClavPar           0.0
# ClavTem           0.0
# Drugs             0.0
# Ethnicity         0.0
# FontBulg          0.0
# GCSEye            0.0
# GCSGroup          0.0
# GCSMotor          0.0
# GCSTotal          0.0
# GCSVerbal         0.0
# Gender            0.0
# HASeverity        0.0
# HAStart           0.0
# HA_verb           0.0
# Hema              0.0
# HemaLoc           0.0
# HemaSize          0.0
# InjuryMech        0.0
# Intubated         0.0
# LOCSeparate       0.0
# LocLen            0.0
# NeuroD            0.0
# NeuroDCranial     0.0
# NeuroDMotor       0.0
# NeuroDOth         0.0
# NeuroDReflex      0.0
# ...

# %% [markdown]
# Here we got one more issue all the variables are not treated as categorical and age as numerical. We need to transform it.

# %% [markdown]
# Now convert age to integer and rest of the variables to category.

# %%
TBI['AgeinYears'] = pd.to_numeric(TBI['AgeinYears'])
for col in list(TBI):
        if col not in ['AgeinYears']:
            TBI[col] = TBI[col].astype('category')

# %%
TBI.dtypes
# Out:
# AMS               category
# AMSAgitated       category
# AMSOth            category
# AMSRepeat         category
# AMSSleep          category
# AMSSlow           category
# ActNorm           category
# AgeinYears           int64
# Amnesia_verb      category
# Clav              category
# ClavFace          category
# ClavFro           category
# ClavNeck          category
# ClavOcc           category
# ClavPar           category
# ClavTem           category
# Drugs             category
# Ethnicity         category
# FontBulg          category
# GCSEye            category
# GCSGroup          category
# GCSMotor          category
# GCSTotal          category
# GCSVerbal         category
# Gender            category
# HASeverity        category
# HAStart           category
# HA_verb           category
# Hema              category
# HemaLoc           category
# HemaSize          category
# InjuryMech        category
# Intubated         category
# LOCSeparate       category
# ...

# %%
TBI.head()
# Out:
#    AMS     AMSAgitated          AMSOth       AMSRepeat        AMSSleep         AMSSlow ActNorm  AgeinYears           Amnesia_verb Clav        ClavFace         ClavFro        ClavNeck         ClavOcc         ClavPar         ClavTem Drugs     Ethnicity   FontBulg       GCSEye GCSGroup                                GCSMotor GCSTotal                   GCSVerbal  Gender                HASeverity               HAStart                HA_verb Hema            HemaLoc         HemaSize                                    InjuryMech Intubated LOCSeparate          LocLen NeuroD   NeuroDCranial     NeuroDMotor       NeuroDOth    NeuroDReflex   NeuroDSensory OSI      OSIAbdomen       OSICspine          OSICut    OSIExtremity        OSIFlank          OSIOth       OSIPelvis Paralyzed PosIntFinal   Race SFxBas       SFxBasHem       SFxBasOto       SFxBasPer       SFxBasRet       SFxBasRhi SFxPalp  SFxPalpDepress Sedated Seiz         SeizLen       SeizOccur Vomit                      VomitLast  \
# ...

# %% [markdown]
# Now the data looks perfect for feature engineering to select important variables to create an model.
